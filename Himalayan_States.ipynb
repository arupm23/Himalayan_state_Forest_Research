# %% [markdown]
# <a href="https://colab.research.google.com/github/arupm23/Himalayan_state_Forest_Research/blob/main/Himalayan_States.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df= pd.read_csv("/Forest_Cover_Himalayan_2019 - Sheet1.csv")

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.head(5)
# Out:
#   Unnamed: 0        Unnamed: 1                  2019 Assessement  \
# 0   District  Shape file Area#                 Very dense forest
# 1   Anantnag             2,727                            126.55
# 2  Bandipura             2,676                            270.85
# 3    Badgam              1,250                            100.85
# 4   Baramula             2,062                            287.57
#
#            Unnamed: 3   Unnamed: 4    Unnamed: 5             Unnamed: 6  \
# 0   Mod. Dense forest  Open forest         Total   % of shape file Area
# 1              455.28       492.36      1,074.19                  39.39
# 2              177.16       194.83        642.84                  24.02
# 3               76.04       164.95        341.84                  27.35
# 4               211.9       370.79        870.26                   42.2
#
#                        Unnamed: 7  Unnamed: 8 Unnamed: 9
# 0      Change wrt 2017 Assessment         NaN      Scrub
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0 Unnamed: 1                  2019 Assessement Unnamed: 3  \
# 19        Samba        921                                 0     124.26
# 20     Shupiyan        505                              62.5      37.22
# 21     Srinagar        282                              0.24      20.03
# 22     Udhampur      2,280                            115.42     624.03
# 23  Grand Total     53,258                          4,202.86   7,952.47
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9
# 19     207.53     331.79      36.02      18.79         NaN      12.59
# 20     224.33     324.05      64.17      46.05         NaN          1
# 21      24.97      45.24      16.04      18.24         NaN          0
# 22     634.57   1,374.02      60.26     -27.98         NaN      22.45
# 23   8,967.26  21,122.59      39.66     347.59         NaN     249.55

# %%
df.rename(columns={"Unnamed":"District"})
# Out:
#       Unnamed: 0        Unnamed: 1                  2019 Assessement  \
# 0       District  Shape file Area#                 Very dense forest
# 1       Anantnag             2,727                            126.55
# 2      Bandipura             2,676                            270.85
# 3        Badgam              1,250                            100.85
# 4       Baramula             2,062                            287.57
# 5           Doda             2,411                            327.98
# 6      Ganderbal             1,620                            129.36
# 7          Jammu             2,407                                 0
# 8         Kathua             2,512                            108.16
# 9       Kishtwar             8,179                            235.96
# 10        Kulgam             1,265                             84.92
# 11       Kupwara             2,744                            783.42
# 12        Mirpur             3,759                                 0
# ...

# %%
df.dropna(axis='columns')
# Out:
#       Unnamed: 0        Unnamed: 1                  2019 Assessement  \
# 0       District  Shape file Area#                 Very dense forest
# 1       Anantnag             2,727                            126.55
# 2      Bandipura             2,676                            270.85
# 3        Badgam              1,250                            100.85
# 4       Baramula             2,062                            287.57
# 5           Doda             2,411                            327.98
# 6      Ganderbal             1,620                            129.36
# 7          Jammu             2,407                                 0
# 8         Kathua             2,512                            108.16
# 9       Kishtwar             8,179                            235.96
# 10        Kulgam             1,265                             84.92
# 11       Kupwara             2,744                            783.42
# 12        Mirpur             3,759                                 0
# ...

# %%
df.dropna(how="all")
# Out:
#       Unnamed: 0        Unnamed: 1                  2019 Assessement  \
# 0       District  Shape file Area#                 Very dense forest
# 1       Anantnag             2,727                            126.55
# 2      Bandipura             2,676                            270.85
# 3        Badgam              1,250                            100.85
# 4       Baramula             2,062                            287.57
# 5           Doda             2,411                            327.98
# 6      Ganderbal             1,620                            129.36
# 7          Jammu             2,407                                 0
# 8         Kathua             2,512                            108.16
# 9       Kishtwar             8,179                            235.96
# 10        Kulgam             1,265                             84.92
# 11       Kupwara             2,744                            783.42
# 12        Mirpur             3,759                                 0
# ...

# %%
df.dropna(axis="columns")
# Out:
#       Unnamed: 0        Unnamed: 1                  2019 Assessement  \
# 0       District  Shape file Area#                 Very dense forest
# 1       Anantnag             2,727                            126.55
# 2      Bandipura             2,676                            270.85
# 3        Badgam              1,250                            100.85
# 4       Baramula             2,062                            287.57
# 5           Doda             2,411                            327.98
# 6      Ganderbal             1,620                            129.36
# 7          Jammu             2,407                                 0
# 8         Kathua             2,512                            108.16
# 9       Kishtwar             8,179                            235.96
# 10        Kulgam             1,265                             84.92
# 11       Kupwara             2,744                            783.42
# 12        Mirpur             3,759                                 0
# ...

# %%
df.rename(columns={"Unnamed: 0":"District"})
# Out:
#         District        Unnamed: 1                  2019 Assessement  \
# 0       District  Shape file Area#                 Very dense forest
# 1       Anantnag             2,727                            126.55
# 2      Bandipura             2,676                            270.85
# 3        Badgam              1,250                            100.85
# 4       Baramula             2,062                            287.57
# 5           Doda             2,411                            327.98
# 6      Ganderbal             1,620                            129.36
# 7          Jammu             2,407                                 0
# 8         Kathua             2,512                            108.16
# 9       Kishtwar             8,179                            235.96
# 10        Kulgam             1,265                             84.92
# 11       Kupwara             2,744                            783.42
# 12        Mirpur             3,759                                 0
# ...

# %%
df.rename(columns={"Unnamed: 0":"District","Unnamed: 1":"Shape file Area#","2019 Assessement":"Very dense forest","Unnamed: 3":"Mod. Dense forest","Unnamed: 4":"Open forest","Unnamed: 5":"Total","Unnamed: 6":"% of shape file Area","Unnamed: 7":"Change wrt 2017 Assessment","Unnamed: 9":"Scrub"})
# Out:
#         District  Shape file Area#                  2019 Assessement  \
# 0       District  Shape file Area#                 Very dense forest
# 1       Anantnag             2,727                            126.55
# 2      Bandipura             2,676                            270.85
# 3        Badgam              1,250                            100.85
# 4       Baramula             2,062                            287.57
# 5           Doda             2,411                            327.98
# 6      Ganderbal             1,620                            129.36
# 7          Jammu             2,407                                 0
# 8         Kathua             2,512                            108.16
# 9       Kishtwar             8,179                            235.96
# 10        Kulgam             1,265                             84.92
# 11       Kupwara             2,744                            783.42
# 12        Mirpur             3,759                                 0
# ...

# %%
df=df.drop(labels="Unnamed: 8",axis=1)

# %%
df.head(5)
# Out:
#   Unnamed: 0        Unnamed: 1                  2019 Assessement  \
# 0   District  Shape file Area#                 Very dense forest
# 1   Anantnag             2,727                            126.55
# 2  Bandipura             2,676                            270.85
# 3    Badgam              1,250                            100.85
# 4   Baramula             2,062                            287.57
#
#            Unnamed: 3   Unnamed: 4    Unnamed: 5             Unnamed: 6  \
# 0   Mod. Dense forest  Open forest         Total   % of shape file Area
# 1              455.28       492.36      1,074.19                  39.39
# 2              177.16       194.83        642.84                  24.02
# 3               76.04       164.95        341.84                  27.35
# 4               211.9       370.79        870.26                   42.2
#
#                        Unnamed: 7 Unnamed: 9
# 0      Change wrt 2017 Assessment      Scrub
# 1                           49.19       0.77
# ...

# %%
df=df.rename(columns={"Unnamed: 0":"District","Unnamed: 1":"Shape file Area#","2019 Assessement":"Very dense forest","Unnamed: 3":"Mod. Dense forest","Unnamed: 4":"Open forest","Unnamed: 5":"Total","Unnamed: 6":"% of shape file Area","Unnamed: 7":"Change wrt 2017 Assessment","Unnamed: 9":"Scrub"})

# %%
df.head(5)
# Out:
#     District  Shape file Area#                  2019 Assessement  \
# 0   District  Shape file Area#                 Very dense forest
# 1   Anantnag             2,727                            126.55
# 2  Bandipura             2,676                            270.85
# 3    Badgam              1,250                            100.85
# 4   Baramula             2,062                            287.57
#
#     Mod. Dense forest  Open forest         Total   % of shape file Area  \
# 0   Mod. Dense forest  Open forest         Total   % of shape file Area
# 1              455.28       492.36      1,074.19                  39.39
# 2              177.16       194.83        642.84                  24.02
# 3               76.04       164.95        341.84                  27.35
# 4               211.9       370.79        870.26                   42.2
#
#        Change wrt 2017 Assessment      Scrub
# 0      Change wrt 2017 Assessment      Scrub
# 1                           49.19       0.77
# ...

# %%
df.head(5)
# Out:
#     District Shape file Area#                  2019 Assessement  \
# 1   Anantnag            2,727                            126.55
# 2  Bandipura            2,676                            270.85
# 3    Badgam             1,250                            100.85
# 4   Baramula            2,062                            287.57
# 5       Doda            2,411                            327.98
#
#   Mod. Dense forest Open forest     Total % of shape file Area  \
# 1            455.28      492.36  1,074.19                39.39
# 2            177.16      194.83    642.84                24.02
# 3             76.04      164.95    341.84                27.35
# 4             211.9      370.79    870.26                 42.2
# 5             703.5      454.45  1,485.93                61.63
#
#   Change wrt 2017 Assessment Scrub
# 1                      49.19  0.77
# 2                      34.84  3.53
# 3                      49.84    16
# 4                      63.26  7.05
# ...

# %%
import matplotlib.pyplot as plt

labels = 'S1', 'S2', 'S3'
sections = [0, 66, 24]
colors = ['c', 'g', 'y']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.1, 0),
        autopct = '%1.2f%%')

plt.axis('equal') # Try commenting this out.
plt.title('Pie Chart Example')
plt.show()

# %%
df.rename(columns ={"2019 Assessement":"Very dense forest"}, inplace=True)

# %%
df.head(4)
# Out:
#   Verydenseforest Mod. Dense forest Open forest
# 1          126.55            455.28      492.36
# 2          270.85            177.16      194.83
# 3          100.85             76.04      164.95
# 4          287.57             211.9      370.79

# %%
df = df.rename(columns={'                 2019 Assessement':'Very dense forest'})
